# %%
# %load_ext autoreload
# %autoreload 2

# %%
# 重新加载模块以确保使用最新代码
import importlib
import sys
if 'Download' in sys.modules:
    importlib.reload(sys.modules['Download'])

from Download import EarthdataDownloader, download_earthdata

# %%
# 配置参数
geojson_path = "../../boundary/zhengzhou.geojson"
short_name = "CYGNSS_L1_V3.2"
download_dir = f"/media/hl/Expansion/Collection/{short_name}/"
start_time = "2020-07-01T00:00:00Z"
end_time = "2020-07-31T23:59:59Z"

print("开始执行 Earthdata 下载流程...")

try:
    downloaded_files = download_earthdata(
        dataset_short_name=short_name,
        geojson_path=geojson_path,
        local_download_dir=download_dir,
        start_time=start_time,
        end_time=end_time
    )
    
    print(f"下载完成！共下载了 {len(downloaded_files)} 个文件")
    for file_path in downloaded_files[:5]:  # 显示前5个文件
        print(f"  - {file_path}")
    if len(downloaded_files) > 5:
        print(f"  ... 还有 {len(downloaded_files) - 5} 个文件")
        
except Exception as e:
    print(f"下载过程中出现错误: {e}")
    import traceback
    traceback.print_exc()
# Out:
# INFO:Download:EarthdataDownloader 实例已创建。
# INFO:Download:正在登录 Earthdata...
# INFO:Download:正在登录 Earthdata...
# 开始执行 Earthdata 下载流程...
# INFO:Download:登录成功！
# INFO:Download:正在从 ../../boundary/zhengzhou.geojson 加载地理范围...
# INFO:Download:地理范围加载成功。
# INFO:Download:边界坐标: 西经 112.714796, 南纬 34.264049, 东经 114.206024, 北纬 34.984173
# INFO:Download:正在搜索数据集 'CYGNSS_L1_V3.2'...
# INFO:Download:使用边界框搜索: (112.714796, 34.264049, 114.206024, 34.984173)
# INFO:Download:正在从 ../../boundary/zhengzhou.geojson 加载地理范围...
# INFO:Download:地理范围加载成功。
# INFO:Download:边界坐标: 西经 112.714796, 南纬 34.264049, 东经 114.206024, 北纬 34.984173
# INFO:Download:正在搜索数据集 'CYGNSS_L1_V3.2'...
# INFO:Download:使用边界框搜索: (112.714796, 34.264049, 114.206024, 34.984173)
# INFO:earthaccess.api:Granules found: 8
# INFO:earthaccess.api:Granules found: 8
# INFO:Download:搜索完成，共找到 8 条数据。
# INFO:Download:准备下载 8 个文件至 /media/hl/Expansion/Collection/CYGNSS_L1_V3.2...
# INFO:earthaccess.store: Getting 8 granules, approx download size: 8.45 GB
# ...

# %%
# 配置参数
geojson_path = "../../boundary/zhengzhou.geojson"
short_name = "GPM_3IMERGHHE"
download_dir = f"/media/hl/Expansion/Collection/{short_name}/"
start_time = "2020-07-01T00:00:00Z"
end_time = "2020-07-31T23:59:59Z"

print("开始执行 Earthdata 下载流程...")

try:
    downloaded_files = download_earthdata(
        dataset_short_name=short_name,
        geojson_path=geojson_path,
        local_download_dir=download_dir,
        start_time=start_time,
        end_time=end_time
    )
    
    print(f"下载完成！共下载了 {len(downloaded_files)} 个文件")
    for file_path in downloaded_files[:5]:  # 显示前5个文件
        print(f"  - {file_path}")
    if len(downloaded_files) > 5:
        print(f"  ... 还有 {len(downloaded_files) - 5} 个文件")
        
except Exception as e:
    print(f"下载过程中出现错误: {e}")
    import traceback
    traceback.print_exc()
# Out:
# INFO:Download:EarthdataDownloader 实例已创建。
# INFO:Download:正在登录 Earthdata...
# 开始执行 Earthdata 下载流程...
# INFO:Download:登录成功！
# INFO:Download:正在从 ../../boundary/zhengzhou.geojson 加载地理范围...
# INFO:Download:地理范围加载成功。
# INFO:Download:边界坐标: 西经 112.714796, 南纬 34.264049, 东经 114.206024, 北纬 34.984173
# INFO:Download:正在搜索数据集 'GPM_3IMERGHHE'...
# INFO:Download:使用边界框搜索: (112.714796, 34.264049, 114.206024, 34.984173)
# INFO:earthaccess.api:Granules found: 1488
# INFO:Download:搜索完成，共找到 1488 条数据。
# INFO:Download:准备下载 1488 个文件至 /media/hl/Expansion/Collection/GPM_3IMERGHHE...
# INFO:earthaccess.store: Getting 1488 granules, approx download size: 11.03 GB
# QUEUEING TASKS | :   0%|          | 0/1488 [00:00<?, ?it/s]INFO:earthaccess.store:File 3B-HHR-E.MS.MRG.3IMERG.20200701-S000000-E002959.0000.V07B.HDF5 already downloaded
# INFO:earthaccess.store:File 3B-HHR-E.MS.MRG.3IMERG.20200701-S010000-E012959.0060.V07B.HDF5 already downloaded
# ...
